# %%
#replace
language = "pytgon"
lang = language.replace("g","h",1)
print(lang)
# Out:
# python

# %%
#replace & limits
usernames = ['the blueman', 'sorted hedgehog', 'infinite lagoon']
for a in usernames:
    a= a.replace(' ','_',1)
    print(a)
# Out:
# the_blueman
# sorted_hedgehog
# infinite_lagoon

# %%
# sourcery skip: merge-list-append, move-assign-in-block
seconds = [1.23, 1.45, 1.02]
current = 1.11
seconds.append(current)
print(seconds)
# Out:
# [1.23, 1.45, 1.02, 1.11]

# %%
red=(1,2,3)
blue=(4,5,6)
white=(8,9,0) 
color_codes = (red,white,blue)

print(color_codes)
# Out:
# ((1, 2, 3), (8, 9, 0), (4, 5, 6))

# %%
mood ="happy"
strength = float(1.23)
rank = int(9)

print(mood,strength,rank)
# Out:
# happy 1.23 9

# %%
tempertures =[float(1.2),int(3),"doe"]
print(tempertures)
# Out:
# [1.2, 3, 'doe']

# %%
#index and enumerate
products = ['table', 'chair', 'door']
for index, a in enumerate(products):
    print(index,a)
# Out:
# 0 table
# 1 chair
# 2 door

# %%
#f string
filenames = ['document', 'report', 'presentation']
for index, a in enumerate(filenames):
    text = f"{index}-{a}.txt"
    print(text)
# Out:
# 0-document.txt
# 1-report.txt
# 2-presentation.txt

# %%
#f-strng & title
filenames = ['document', 'report', 'presentation']
for index, a in enumerate(filenames):
    text = f"{index}-{a.title()}.txt"
    print(text)
# Out:
# 0-Document.txt
# 1-Report.txt
# 2-Presentation.txt

# %%
#remove
seconds = [1.23, 1.45, 1.02, 1.11]
seconds.remove(1.45)
print(seconds)
# Out:
# [1.23, 1.02, 1.11]

# %%
# len function
mystring = "meoweoireofn"
mylist = [1,2,3,4,5]
print(len(mystring))
print(len(mylist))
# Out:
# 12
# 5

# %%
#sort
measurements = [177.8, 175.8, 166.9, 182.5]
measurements.sort()
print(measurements)
# Out:
# [166.9, 175.8, 177.8, 182.5]

# %%
#zip
content = [me, too, mama]
filename = ["doc.txt","mo.txt", "perd.txt"]

for content, filename in zip(contents,filenames):
    file = open(filename,"w")
    file.write(content)

# %%
# read files
file = open("bear.txt", "r")
content = file.read()
file.close()
 
print(content)

# %%
# Read File, Modify, and Print
file = open('essay.txt', 'r')
a = file.read()
file.close()
print(a.title())

# %%
# Read File and Analyze its Content 
file = open("essay.txt", 'r')
content = file.read()
file.close()
 
nr_chars = len(content)
message = f"The file contains {nr_chars} characters."
print(message)

# %%
#Creating a Text File
file = open('file.txt', 'w')
file.write('snail')
file.close()

# %%
# zip- join two or more iterables into tuples
countries = ["Albania", "Belgium", "Canada", "Denmark", "Ethiopia", "France"]
filenames = ['a.txt', 'b.txt', 'c.txt', 'd.txt', 'e.txt', 'f.txt']

for content, filename in zip(countries, filenames):
    file = open(filename, 'w')
    file.write(content)
    file.close()

# %%
#Creating Multiple Text Files
countries = ["Albania", "Belgium", "Canada", "Denmark", "Ethiopia", "France"]

for cont in countries:
    file = open(f"{cont}.txt",'w')
    file.write(cont)
    file.close()

# %%
# List Comprehenson
names = ["john smith", "jay santi", "eva kuki"]
names = [name.title() for name in names]
print(names)

usernames = ["john 1990", "alberta1970", "magnola2000"]
usernames =[len(name) for name in usernames]
print(usernames)



user_entries = ['10', '19.1', '20']
user_entries=[float(a) for a in user_entries]
print(user_entries)


user_entries = ['10', '19.1', '20']

user_numbers = [float(item) for item in user_entries]
 
# Print the sum of the numbers
print(sum(user_numbers))

# %%
#use when the file already made
#'r' is default with this function


with open('todos.txt','r') as file:
            todos = file.readlines()
# as the same as except their are no close()

file = open('todos.txt','r')
        todos = file.readlines()
        file.close()

# %%
date = input("Enter in today date?")
mood = input("How do you rate your mood today from 1 to 10?")
thoughts = input("Let your thought flow: \n")

with open(f"../thoughts/{date}.txt","w") as file:
    file.write(mood)
    file.write(thoughts)

# %%
# create a text file and as the name in the file using the with function

languages = ['English', 'German', 'Spanish']

for a in languages:
    with open(f"{a}.txt","w") as file:
        file.write(a)

# %%
# read one text file and create/write another one
with open('story.txt','r')as file:
    content= file.read()
with open('story_copy.txt','w') as file:
        file.write(content)

# %%
# make a password that check the length of the password great then 7 char.
password = input('Enter a new password: ')

if len(password)>=7:
    print('Great password there!')
else:
    print('Your password is weak.')

# %%
#set up a dictionary

day_temperatures = {'morning': 5.1, 'noon': 6.1, 'evening': 10.2}

# tuple dictionary with the vaule

day_temperatures = {'morning': (5.12,5.4,5.6), 'noon': (6.14,8.4,9.4), 'evening': (10.246,7.4,5.4)}

# %%
#percentage Calculator with Error Handling

try:
    total_value = float(input("Enter total value: "))
    value = float(input("Enter value: "))
    formla = float(value/total_value*100)
    print(f"That is {formla}%")

except ValueError:
    print('You need to enter a number. Run the program again.')

# %%
filenames = ["report.txt", "downloads.txt", "success.txt", "folders.txt"]
 
# Print filenames without their extensions and with the first letter capitalized
for filename in filenames:
    print(filename[:-4].capitalize())  # Capitalizes the first letter of the filename without the extension

# %%
# Reverse a list without using a function
orginal = [1,2,3,4,5]
new=[]
for temp in a:
    new=[temp]+new
print(new)
# Out:
# [5, 4, 3, 2, 1]

# %%
print(dir(list))
print(help(list.count))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# Help on method_descriptor:
#
# count(self, value, /) unbound builtins.list method
#     Return number of occurrences of value.
#
# None

# %%
# custom function

def greet():
    message= "hello"
    new_message = message.capitalize()
    return new_message

greeting = greet()
print(greeting)
# Out:
# Hello

# %%
#slicer()[start : end]

data= file.readlines()[1:]
or
value =data[1:]
#better to use

# %%
def get_max():
    grades = [9.6, 9.2, 9.7]
    maximum = max(grades)
    return maximum
a= get_max()
print(a)
# Out:
# 9.7

# %%
def get_max():
    grades = [9.6, 9.2, 9.7]
    maximum = max(grades)
    minimum = min(grades)
    message = f"Max: {maximum}, Min: {minimum}"
    return message
print(get_max())
# Out:
# Max: 9.7, Min: 9.2

# %%
def format_filename():
    filename = "report.txt"
    a= filename.capitalize()[:6]
    return a

print(format_filename())
# Out:
# Report

# %%
def square_number():
    number :int = 5
    result= number**2
    return result
    
print(square_number())
# Out:
# 25

# %%
def strength(password):
    
    if len(password)>=8 and password.isupper() and password.isdigit():
        print("Strong Password")
    else:
        print("Weak Password")
        return
    
a="Ae4uhy7h7*"
strength(a)
# Out:
# Weak Password

# %%
def strength(password):
    # Create an empty dictionary to store the strength attributes
    result = {}
 
    # Check the length of the password
    if len(password) >= 8:
        result["length"] = True
    else:
        result["length"] = False
 
    # Check if the password contains a digit and an uppercase letter
    digit = False
    uppercase = False
 
    # Iterate over each character in the password
    for i in password:
        # Check if the character is a digit
        if i.isdigit():
            digit = True
        # Check if the character is an uppercase letter
        if i.isupper():
            uppercase = True
 
    # Store the results in the dictionary
    result["digits"] = digit
    result["upper-case"] = uppercase
 
    # Check if all the strength attributes are True
    if all(result.values()):
        # Return "Strong Password" if all attributes are True
        return "Strong Password"
    else:
        # Return "Weak Password" if any attribute is False
        return "Weak Password"

# %%
foo=[10, 20, 30, 40]
def avg (foo):
    a = sum(foo)/ len(foo)
    return a
avg(foo)
# Out:
# 25.0

# %%
def person(name):
    a = f'Hi {name}'
    return a

person("Lisa")
# Out:
# 'Hi Lisa'

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
#MULTIPLE line string

print(""" I love 
cheese""")
# Out:
#  I love
# chees

# %%
#decoupling- separating the responsible of a function 
# any to two functions

# %%
# defualt values in function
def get_age(year_of_birth, current_year=2025):
    return current_year - year_of_birth

# %%
 #split  and count number
def get_nr_items(user_input="john,lisa, teresa"):
    a= user_input.split(",")
    return len(a)

get_nr_items()
# Out:
# 3

# %%
def temp(a):
    if a >7:
        return "Warm"
    else:
        return "cold"

# %%
"""Water State Checker
Define a  water_state function that:
(1) gets a temperature parameter
(2) returns the string "Solid" if the temperature is less than or equal to 0
(3) returns "Liquid" if the temperature is greater than 0, but less than 100.
(4) returns "Gas" if the temperature is greater than or equal to 100."""

def water_state(temperature):
    
    if temperature <=0:
        return "Solid"
    elif 0 < temperature <100:
        return "Liquid"
    else:
        return "Gas"

# %%
FREEZING_POINT = 0
BOILING_POINT = 100
 
# Define a function named water_state that takes one parameter: temperature
def water_state(temperature):
    # Check if the temperature is less than or equal to the freezing point
    if temperature <= FREEZING_POINT:
        return "Solid" 
    # Check if the temperature is between the freezing point and boiling point
    elif FREEZING_POINT < temperature < BOILING_POINT:
        return "Liquid" 
    # Return "Gas" for all other cases
    else:
        return "Gas"
