# %% [markdown]
# # load the data frame

# %%
import pandas as pd

# %%
df = pd.read_csv("data_small/TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %% [markdown]
# # Show certain rows

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %% [markdown]
# # Show certain columns

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
df[['   TG','    DATE',]]
# Out:
#          TG       DATE
# 0        21 1860-01-01
# 1        46 1860-01-02
# 2        31 1860-01-03
# 3        37 1860-01-04
# 4        31 1860-01-05
# ...     ...        ...
# 59316 -9999 2022-05-27
# 59317 -9999 2022-05-28
# 59318 -9999 2022-05-29
# 59319 -9999 2022-05-30
# 59320 -9999 2022-05-31
#
# [59321 rows x 2 columns]

# %% [markdown]
# # Simple Statistics and filtering

# %%
df.loc[df['   TG']!=-9999]
# Out:
# 0        21
# 1        46
# 2        31
# 3        37
# 4        31
#          ..
# 53655    80
# 53656    70
# 53657    71
# 53658    63
# 53659    84
# Name:    TG, Length: 53103, dtype: int64

# %%
df.loc[df['   TG']!=-9999]['   TG']
# Out:
# 0        21
# 1        46
# 2        31
# 3        37
# 4        31
#          ..
# 53655    80
# 53656    70
# 53657    71
# 53658    63
# 53659    84
# Name:    TG, Length: 53103, dtype: int64

# %%
df.loc[df['   TG']!=-9999]['   TG'].max()/10
# Out:
# np.float64(26.2)

# %%
df.loc[df['   TG']!=-9999]['   TG'].min()/10
# Out:
# np.float64(-28.8)

# %%
df['   TG'].hist()
# Out:
# <Axes: >

# %%
df.loc[df['   TG']!=-9999]['   TG'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Get Certain Cell

# %%
df.loc[df['    DATE']=="1860-01-05"]['   TG'].squeeze()/10
# Out:
# np.float64(3.1)

# %%
df.loc[df['   TG']==df['   TG'].max()]['    DATE'].squeeze()
# Out:
# Timestamp('1868-08-16 00:00:00')

# %%
df.loc[3,'   TG']
# Out:
# np.int64(37)

# %% [markdown]
# Calculate a new column out of existing column

# %%
df["TG"]=df['   TG']/10

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG
# 0          1   35381 1860-01-01     21      0    2.1
# 1          1   35381 1860-01-02     46      0    4.6
# 2          1   35381 1860-01-03     31      0    3.1
# 3          1   35381 1860-01-04     37      0    3.7
# 4          1   35381 1860-01-05     31      0    3.1
# ...      ...     ...        ...    ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9
# 59317      1   35381 2022-05-28  -9999      9 -999.9
# 59318      1   35381 2022-05-29  -9999      9 -999.9
# 59319      1   35381 2022-05-30  -9999      9 -999.9
# 59320      1   35381 2022-05-31  -9999      9 -999.9
#
# [59321 rows x 6 columns]

# %%
df["F degree"] = df['   TG']*(9/5)+32

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG  F degree
# 0          1   35381 1860-01-01     21      0    2.1      69.8
# 1          1   35381 1860-01-02     46      0    4.6     114.8
# 2          1   35381 1860-01-03     31      0    3.1      87.8
# 3          1   35381 1860-01-04     37      0    3.7      98.6
# 4          1   35381 1860-01-05     31      0    3.1      87.8
# ...      ...     ...        ...    ...    ...    ...       ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9  -17966.2
# 59317      1   35381 2022-05-28  -9999      9 -999.9  -17966.2
# 59318      1   35381 2022-05-29  -9999      9 -999.9  -17966.2
# 59319      1   35381 2022-05-30  -9999      9 -999.9  -17966.2
# 59320      1   35381 2022-05-31  -9999      9 -999.9  -17966.2
#
# [59321 rows x 7 columns]

# %% [markdown]
# Plotting

# %%
df["F degree"].hist()
# Out:
# <Axes: >
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
a=2

if a>0:

    a+=1

else:

    a-=1

print(a)
# Out:
# 3
